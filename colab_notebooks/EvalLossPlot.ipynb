# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Gráficas de evolución del eval loss

# %%
# LLAMA

# Datos
train_loss = [2.247800, 1.780600, 1.628300, 0.887600, 0.517500, 0.471000,
              0.357700, 0.346600, 0.356400, 0.316200, 0.320900, 0.325300,
              0.288700, 0.289400, 0.292100, 0.260900, 0.276100, 0.278500,
              0.249400, 0.259000, 0.257600, 0.243100, 0.247500, 0.246900,
              0.241600, 0.241100, 0.246000, 0.233200, 0.242000, 0.241100,
              0.235800, 0.230700, 0.226100, 0.232300, 0.231600,	0.227000,
              0.226700, 0.222100, 0.221400, 0.228000, 0.224500, 0.215700,
              0.226400, 0.219300, 0.217300, 0.212900, 0.219600, 0.217200,
              0.217100, 0.216300, 0.213600, 0.217300, 0.215500, 0.209400,
              0.214000, 0.217600, 0.209100, 0.217200, 0.212500, 0.207500]

val_loss =   [2.204458, 1.739607, 1.637814, 0.834445, 0.491741, 0.454734,
              0.373884, 0.351569, 0.348117, 0.328227, 0.316046, 0.314017,
              0.300649, 0.291716, 0.290126, 0.280371, 0.273624, 0.272528,
              0.266137, 0.261433, 0.260790, 0.256487, 0.253120, 0.252481,
              0.249388, 0.246947, 0.246591, 0.244457, 0.242475, 0.242181,
              0.240666, 0.239247, 0.238977, 0.237727, 0.236542, 0.236393,
              0.235237, 0.234216, 0.234073, 0.233246, 0.231893, 0.231866,
              0.230967, 0.230039, 0.230013, 0.228894, 0.228123, 0.228001,
              0.227116, 0.226305, 0.226114, 0.225123, 0.224328, 0.224225,
              0.223166, 0.222482, 0.222358, 0.221241, 0.220720, 0.220555]

epochs = list(range(1, len(train_loss) + 1))  # Ej: [1, 2, 3, ..., 10]
# Crear la figura
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, label='Training Loss', linewidth=2.5)
plt.plot(epochs, val_loss, label='Validation Loss', linewidth=2.5)

# Títulos y leyenda
plt.title('Evolución de LLaMa: Training vs Validation Loss')
plt.xlabel('Épocas')
plt.ylabel('Eval Loss')
plt.legend()
plt.grid(True)

# Montar directorio de drive
from google.colab import drive
drive.mount('/content/drive')

# Guardar o mostrar
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/Colab Notebooks/ft_llama_model/final_model/llama_eval_loss_plot.png", dpi=300)  # para la memoria
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# FALCON

# Datos
train_loss = [3.031100, 2.281300, 2.077100, 0.938000, 0.621200, 0.578300,
              0.389100, 0.324700, 0.318100, 0.282700, 0.281300, 0.272300,
              0.261600, 0.256600, 0.270100, 0.256200, 0.257500, 0.249000,
              0.242700, 0.241000, 0.241000, 0.233900, 0.237900, 0.230800,
              0.226900, 0.223000, 0.219400, 0.206800, 0.212100, 0.207600,
              0.203600, 0.198600, 0.203000, 0.189200, 0.182400, 0.184000,
              0.178600, 0.175400, 0.181000]

val_loss =   [2.925012, 2.240222, 2.097099, 0.858493, 0.623724, 0.591152,
              0.377069, 0.324510, 0.319282, 0.284286, 0.276059, 0.274824,
              0.267861, 0.263416, 0.262678, 0.257869, 0.254520, 0.253841,
              0.250235, 0.246399, 0.245716, 0.241814, 0.238371, 0.237738,
              0.233356, 0.229586, 0.228679, 0.223891, 0.219184, 0.218163,
              0.211551, 0.206038, 0.204830, 0.197545, 0.197520, 0.197515,
              0.197515, 0.197517, 0.197519]

epochs = list(range(1, len(train_loss) + 1))  # Ej: [1, 2, 3, ..., 10]
# Crear la figura
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, label='Training Loss', linewidth=2.5)
plt.plot(epochs, val_loss, label='Validation Loss', linewidth=2.5)

# Línea vertical en la época de early stopping
plt.axvline(x=36, color='red', linestyle='--', linewidth=1.5, label=f"Early Stopping (Epoch {36})")

# Títulos y leyenda
plt.title('Evolución de Falcon: Training vs Validation Loss')
plt.xlabel('Épocas')
plt.ylabel('Eval Loss')
plt.legend()
plt.grid(True)

# Montar directorio de drive
from google.colab import drive
drive.mount('/content/drive')

# Guardar o mostrar
plt.tight_layout()
plt.savefig("/content/drive/MyDrive/Colab Notebooks/ft_falcon_model/final_model/falcon_eval_loss_plot.png", dpi=300)  # para la memoria
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
